# %%
# !pip install -q transformers datasets wandb

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nityamittal2000 (mnitya-university-of-michigan) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/fineweb-edu-sample-1B-hf
# Out:
# data-00000-of-00024.arrow  data-00009-of-00024.arrow  data-00018-of-00024.arrow
# data-00001-of-00024.arrow  data-00010-of-00024.arrow  data-00019-of-00024.arrow
# data-00002-of-00024.arrow  data-00011-of-00024.arrow  data-00020-of-00024.arrow
# data-00003-of-00024.arrow  data-00012-of-00024.arrow  data-00021-of-00024.arrow
# data-00004-of-00024.arrow  data-00013-of-00024.arrow  data-00022-of-00024.arrow
# data-00005-of-00024.arrow  data-00014-of-00024.arrow  data-00023-of-00024.arrow
# data-00006-of-00024.arrow  data-00015-of-00024.arrow  dataset_info.json
# data-00007-of-00024.arrow  data-00016-of-00024.arrow  state.json
# data-00008-of-00024.arrow  data-00017-of-00024.arrow

# %%
# !python pretrain_gpt.py \
    --data_path "/content/drive/MyDrive/fineweb-edu-sample-1B-hf" \
    --data_format arrow \
    --batch_size 16 \
    --learning_rate 6e-3 \
    --weight_decay 0.1 \
    --max_epochs 1 \
    --context_length 1024 \
    --emb_dim 512 \
    --n_layers 12 \
    --n_heads 8 \
    --target_tokens 1200000000 \
    --save_every 200 \
    --eval_every 500 \
    --eval_batch_size 8 \
    --device cuda \
    --num_workers 2 \
    --output_dir "./models/arrow_colab" \
    --wandb_project eecs595-gpt-pretraining \
    --wandb_run_name "colab-arrow-1b"
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Step:  94% 41960/44501 [5:31:57<04:41,  9.03it/s]  entered batch loop, step 41960
#
# Step:  94% 41961/44501 [5:31:57<04:40,  9.04it/s]  entered batch loop, step 41961
#
# Step:  94% 41962/44501 [5:31:57<04:41,  9.01it/s]  entered batch loop, step 41962
#
# Step:  94% 41963/44501 [5:31:58<04:43,  8.95it/s]  entered batch loop, step 41963
#
# Step:  94% 41964/44501 [5:31:58<04:40,  9.06it/s]  entered batch loop, step 41964
#
# Step:  94% 41965/44501 [5:31:58<04:39,  9.06it/s]  entered batch loop, step 41965
#
# Step:  94% 41966/44501 [5:31:58<04:40,  9.02it/s]  entered batch loop, step 41966
#
# Step:  94% 41967/44501 [5:31:58<04:40,  9.04it/s]  entered batch loop, step 41967
#
# Step:  94% 41968/44501 [5:31:58<05:19,  7.92it/s]  entered batch loop, step 41968
#   entered batch loop, step 41969
#
# Step:  94% 41970/44501 [5:31:58<04:35,  9.20it/s]  entered batch loop, step 41970
#
# ...
